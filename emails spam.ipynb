# %%
import pandas as pd
import numpy as np

# %%
import torchtext
from torchtext.data import get_tokenizer

# %%
data = pd.read_csv("/home/mike/Downloads/spam detection/SPAM text message 20170820 - Data.csv")

# %%
data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
y = data.pop('Category')

# %%
data
# Out:
#                                                 Message
# 0     Go until jurong point, crazy.. Available only ...
# 1                         Ok lar... Joking wif u oni...
# 2     Free entry in 2 a wkly comp to win FA Cup fina...
# 3     U dun say so early hor... U c already then say...
# 4     Nah I don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  This is the 2nd time we have tried 2 contact u...
# 5568               Will ü b going to esplanade fr home?
# 5569  Pity, * was in mood for that. So...any other s...
# 5570  The guy did some bitching but I acted like i'd...
# 5571                         Rofl. Its true to its name
#
# [5572 rows x 1 columns]

# %%
tokenizer = get_tokenizer('basic_english')

# %%
sentence = "hi there welcome to my youtube channel"

tokens = tokenizer(sentence)
tokens
# Out:
# ['hi', 'there', 'welcome', 'to', 'my', 'youtube', 'channel']

# %%
tokens = tokenizer(data['Message'][0])
tokens
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  ',',
#  'crazy',
#  '.',
#  '.',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  '.',
#  '.',
#  '.',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat',
#  '.',
#  '.',
#  '.']

# %%
vocab = []

for t in data['Message']:    
    tokens = tokenizer(t)    
    for token in tokens:
        if token not in vocab:
            vocab.append(token)

# %%
len(vocab)
# Out:
# 9193

# %%
vocab.
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  ',',
#  'crazy',
#  '.',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat',
#  'ok',
#  'lar',
#  'joking',
#  'wif',
#  'u',
#  'oni',
#  'free',
#  'entry',
#  '2',
#  'a',
#  'wkly',
#  'comp',
#  'to',
#  'win',
#  'fa',
#  'cup',
#  'final',
#  'tkts',
#  '21st',
#  'may',
#  '2005',
#  'text',
#  '87121',
#  'receive',
#  'question',
#  '(',
#  'std',
#  'txt',
#  'rate',
#  ')',
#  't&c',
#  "'",
#  's',
#  'apply',
#  '08452810075over18',
#  'dun',
#  'say',
#  'so',
#  'early',
#  'hor',
#  'c',
#  'already',
#  'then',
#  'nah',
#  'i',
#  'don',
#  't',
#  'think',
#  'he',
#  'goes',
#  'usf',
#  'lives',
#  'around',
#  'here',
#  'though',
#  'freemsg',
#  'hey',
#  'darling',
#  'it',
#  'been',
#  '3',
#  'week',
#  'now',
#  'and',
#  'no',
#  'word',
#  'back',
#  '!',
#  'd',
#  'like',
#  'some',
# ...

# %%
from torchtext.vocab import vocab, build_vocab_from_iterator
from collections import OrderedDict, Counter

# %%
vocab = build_vocab_from_iterator(data, specials=["<unk>"])

# %%
v2 = vocab(OrderedDict([(token, 1) for token in vocab]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-4fd427551849> in <module>
# ----> 1 v2 = vocab(OrderedDict([(token, 1) for token in vocab]))
#
# TypeError: 'list' object is not callable

# %%
def make_vocab(fn):
  toker = get_tokenizer("basic_english")
  counter_obj = collections.Counter()
  f = open(fn, "r")
  for line in f:
    line = line.strip()
    txt = line.split(",")[1]
    split_and_lowered = toker(txt)
    counter_obj.update(split_and_lowered)
  f.close()
  result = tt.vocab.Vocab(counter_obj, min_freq=1)
  return result

# %%
vocab = make_vocab(data)
#   print("\nVocab itos: ")
#   for i in range(len(vocab)):
#     print(i, vocab.itos[i])
 
#   print("\nEnd demo ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-1f8cd1214514> in <module>
# ----> 1 vocab = make_vocab(data)
#       2 #   print("\nVocab itos: ")
#       3 #   for i in range(len(vocab)):
#       4 #     print(i, vocab.itos[i])
#       5
#
# <ipython-input-59-71993e05abac> in make_vocab(fn)
#       1 def make_vocab(fn):
#       2   toker = get_tokenizer("basic_english")
# ----> 3   counter_obj = collections.Counter()
#       4   f = open(fn, "r")
#       5   for line in f:
#
# NameError: name 'collections' is not defined

# %%
from torchtext.transforms import SentencePieceTokenizer

# %%
transform = SentencePieceTokenizer("spm_model")

# sentence = SentencePieceTokenizer("hi i am mike.")
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-63-5ad470fcb215> in <module>
# ----> 1 transform = SentencePieceTokenizer("spm_model")
#       2
#       3 # sentence = SentencePieceTokenizer("hi i am mike.")
#
# ~/anaconda3/lib/python3.7/site-packages/torchtext/transforms.py in __init__(self, sp_model_path)
#      50     def __init__(self, sp_model_path: str):
#      51         super().__init__()
# ---> 52         self.sp_model = load_sp_model(get_asset_local_path(sp_model_path))
#      53
#      54     def forward(self, input: Any) -> Any:
#
# ~/anaconda3/lib/python3.7/site-packages/torchtext/utils.py in get_asset_local_path(asset_path)
#     226         local_path = asset_path
#     227     else:
# --> 228         local_path = download_from_url(url=asset_path, root=_CACHE_DIR)
#     229     return local_path
#
# ...

# %%
from torchtext.transforms import SentencePieceTokenizer
transform = SentencePieceTokenizer("spm_model")
transform(["hello world", "attention is all you need!"])
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-64-e847c3862b13> in <module>
#       1 from torchtext.transforms import SentencePieceTokenizer
# ----> 2 transform = SentencePieceTokenizer("spm_model")
#       3 transform(["hello world", "attention is all you need!"])
#
# ~/anaconda3/lib/python3.7/site-packages/torchtext/transforms.py in __init__(self, sp_model_path)
#      50     def __init__(self, sp_model_path: str):
#      51         super().__init__()
# ---> 52         self.sp_model = load_sp_model(get_asset_local_path(sp_model_path))
#      53
#      54     def forward(self, input: Any) -> Any:
#
# ~/anaconda3/lib/python3.7/site-packages/torchtext/utils.py in get_asset_local_path(asset_path)
#     226         local_path = asset_path
#     227     else:
# --> 228         local_path = download_from_url(url=asset_path, root=_CACHE_DIR)
# ...
